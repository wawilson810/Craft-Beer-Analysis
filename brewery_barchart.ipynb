# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = './Resources/breweries.csv'
breweries_df = pd.read_csv(path)
breweries_df.drop(columns=['Unnamed: 0'], inplace=True)
breweries_df
# Out:
#       brewery_id                                    brewery_name  \
# 0           1075                         Caldera Brewing Company
# 1           1454                           Broad Ripple Brew Pub
# 2            850                      Moon River Brewing Company
# 3          14879                            Hoppin' Frog Brewery
# 4           2724                   Pacific Coast Brewing Company
# ...          ...                                             ...
# 2321         563              Wild River Brewery & Pizza Company
# 2322       14359                     The Defiant Brewing Company
# 2323        1854            Hereford & Hops Restaurant & Brewpub
# 2324       10434              Mia & Pia's Pizzeria And Brewhouse
# 2325         154  Tremont Brewery / Atlantic Coast Brewing, Ltd.
#
#                City          State                    Address         Zip  \
# 0           Ashland         Oregon            590 Clover Lane       97520
# 1      Indianapolis        Indiana              840 E 65th St       46220
# 2          Savannah        Georgia            21 West Bay St.       31401
# 3             Akron           Ohio         1680 E Waterloo Rd  44306-4523
# 4           Oakland     California         906 Washington St.       94607
# ...             ...            ...                        ...         ...
# 2321    Grants Pass         Oregon            595 NE E Street       97526
# 2322    Pearl River       New York        6 East Dexter Plaza       10965
# 2323         Wausau      Wisconsin           2201 Sherman St.       54401
# 2324  Klamath Falls         Oregon          3545 Summers Lane       97601
# 2325        Waltham  Massachusetts  322 Moody Street, Suite 2       02453
#
#             Country        Lat         Lon
# 0     United States  42.181901 -122.662854
# 1     United States  39.873606  -86.142860
# 2     United States  32.080961  -81.092043
# 3     United States  41.024625  -81.467699
# 4     United States  37.801503 -122.274199
# ...             ...        ...         ...
# 2321  United States  42.439044 -123.317705
# 2322  United States  41.058392  -74.022851
# 2323  United States  44.951859  -89.663439
# 2324  United States  42.193827 -121.737079
# 2325  United States  42.370550  -71.236655
#
# [2326 rows x 9 columns]

# %%
grouped_df = breweries_df.groupby('State')
updated = grouped_df['brewery_id'].count()
updated_df = pd.DataFrame(updated)
new_df = updated_df.sort_values('brewery_id', ascending=False)[0:20]
new_df
# Out:
#                 brewery_id
# State
# California             349
# Washington             140
# Oregon                 124
# Colorado               116
# Michigan               108
# Wisconsin              105
# Pennsylvania           104
# New York               102
# Florida                 69
# North Carolina          66
# Massachusetts           64
# Texas                   62
# Missouri                58
# Illinois                58
# Ohio                    56
# Indiana                 47
# Virginia                47
# Maine                   43
# Minnesota               39
# Arizona                 38

# %%
chart = new_df.plot(kind="bar", title="Top Twenty States with Most Breweries", color="red", figsize=(10,6))
chart.set_ylabel('Number of Breweries')
chart.set_xlabel('State')
plt.legend('')
plt.savefig("Resources/barchart.png", format='png', bbox_inches = "tight")
plt.show()
